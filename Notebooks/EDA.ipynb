# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### **Import the Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##### **Import Dataset**

# %%
df = pd.read_csv(r"D:\Regression\Notebooks\Data\Diamond.csv")
df
# Out:
#             id  carat        cut color clarity  depth  table     x     y
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  \
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
df.shape
# Out:
# (193573, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.tail()
# Out:
#             id  carat        cut color clarity  depth  table     x     y
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  \
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258

# %%
df.sample(5)
# Out:
#             id  carat        cut color clarity  depth  table     x     y
# 150205  150205   0.93    Premium     E     SI1   62.1   59.0  6.27  6.20  \
# 1859      1859   1.59    Premium     H     VS2   62.4   58.0  7.51  7.46
# 108417  108417   0.30    Premium     F     VS2   62.0   58.0  4.30  4.34
# 180677  180677   0.77  Very Good     G     SI1   61.3   60.0  5.91  5.94
# 176144  176144   1.14    Premium     H    VVS2   61.5   59.0  6.71  6.66
#
#            z  price
# 150205  3.87   4226
# 1859    4.67  10819
# 108417  2.68    605
# 180677  3.63   2415
# 176144  4.12   7554

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### **Seperate Numerical & Categorical Columns/Features**

# %%
numerical_columns = df.columns[df.dtypes != 'object']
numerical_columns
# Out:
# Index(['id', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
categorical_columns = df.columns[df.dtypes == 'object']
categorical_columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df[numerical_columns].describe()
# Out:
#                   id          carat          depth          table
# count  193573.000000  193573.000000  193573.000000  193573.000000  \
# mean    96786.000000       0.790688      61.820574      57.227675
# std     55879.856166       0.462688       1.081704       1.918844
# min         0.000000       0.200000      52.100000      49.000000
# 25%     48393.000000       0.400000      61.300000      56.000000
# 50%     96786.000000       0.700000      61.900000      57.000000
# 75%    145179.000000       1.030000      62.400000      58.000000
# max    193572.000000       3.500000      71.600000      79.000000
#
#                    x              y              z          price
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean        5.715312       5.720094       3.534246    3969.155414
# std         1.109422       1.102333       0.688922    4034.374138
# min         0.000000       0.000000       0.000000     326.000000
# ...

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %% [markdown]
# #### **Plots All Numerical Columns**

# %%
plt.figure(figsize=(35, 15))
plt.suptitle("Histplots of Numerical Columns")
for i in enumerate(df[['carat', 'depth', 'table', 'x', 'y', 'z', 'price']]):
    plt.subplot(4,2, i[0]+1)
    sns.histplot(df[i[1]], kde = True)
plt.show()

# %%
plt.figure(figsize=(35, 15))
plt.suptitle("Distplots of Numerical Columns")
for i in enumerate(df[['carat', 'depth', 'table', 'x', 'y', 'z', 'price']]):
    plt.subplot(4,2, i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# C:\Users\Neeta Devke\AppData\Local\Temp\ipykernel_2624\3271546907.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i[1]])
# C:\Users\Neeta Devke\AppData\Local\Temp\ipykernel_2624\3271546907.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i[1]])
# ...

# %%
sns.heatmap(df[['carat', 'depth', 'table', 'x', 'y', 'z', 'price']].corr(), annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(35, 15))
plt.suptitle("Countplots of Numerical Columns")
for i in enumerate(df[['carat', 'depth', 'table', 'x', 'y', 'z', 'price']]):
    plt.subplot(4,2, i[0]+1)
    ax = sns.countplot(x = i[1], data = df)
    plt.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Countplots of Categorical Columns")
for i in enumerate(df[categorical_columns]):
    plt.subplot(2,2, i[0]+1)
    ax = sns.countplot(x = i[1], data = df)
    plt.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Pieplots of Categorical Columns")
for i in enumerate(df[categorical_columns]):
    plt.subplot(2,2, i[0]+1)
    df[i[1]].value_counts().plot.pie(autopct="%.1f%%", ylabel="", startangle=90)
plt.show()

# %%
sns.pairplot(df)

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map = {'Premium':4, 'Very Good':3, 'Ideal':5, 'Good':2, 'Fair':1}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {'F':3, 'J':7, 'G':4, 'E':2, 'D':1, 'H':5, 'I':6}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {'VS2':4, 'SI2':2, 'VS1':5, 'SI1':3, 'IF':8, 'VVS2':6, 'VVS1':7, 'I1':1}

# %% [markdown]
# #### **Apply Map Function**

# %%
df['cut'] = df['cut'].map(cut_map)

# %%
df['color'] = df['color'].map(color_map)

# %%
df['clarity'] = df['clarity'].map(clarity_map)

# %%
df.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
